# %%
print 'Здравствуй, дивный новый мир!'
# Out:
# Здравствуй, дивный новый мир!

# %% [markdown]
# Честно говоря затрудняюсь привести примеры задач, но у меня просьба можете ли Вы писать код не из командной строки?
#
# Так проще будет начинающим, как и я, ориентироваться.
#
# Спасибо!
